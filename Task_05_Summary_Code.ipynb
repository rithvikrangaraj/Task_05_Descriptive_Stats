# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("C:/Users/rithv/Downloads/archive (8)/cbb24.csv")

# Basic Info
print("\nDataset Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nMissing Values:\n", df.isnull().sum())

# Descriptive Summary
summary = df.describe(include='all')
print("\nDescriptive Summary:\n", summary)

# Correlation heatmap (numeric only)
plt.figure(figsize=(14, 10))
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap of Numeric Features")
plt.tight_layout()
plt.show()
# Out:
# Dataset Shape: (362, 23)
#
# Columns: ['TEAM', 'CONF', 'G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG%', 'EFGD%', 'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O', '3P_D', 'ADJ_T', 'WAB', 'POSTSEASON', 'SEED']
#
# Missing Values:
#  TEAM            0
# CONF            0
# G               0
# W               0
# ADJOE           0
# ADJDE           0
# BARTHAG         0
# EFG%            0
# EFGD%           0
# TOR             0
# TORD            0
# ORB             0
# DRB             0
# FTR             0
# FTRD            0
# 2P_O            0
# 2P_D            0
# 3P_O            0
# 3P_D            0
# ADJ_T           0
# WAB             0
# POSTSEASON    294
# SEED          294
# dtype: int64
#
# Descriptive Summary:
#             TEAM CONF           G           W       ADJOE       ADJDE  \
# count       362  362  362.000000  362.000000  362.000000  362.000000
# unique      362   33         NaN         NaN         NaN         NaN
# top     Houston  A10         NaN         NaN         NaN         NaN
# freq          1   15         NaN         NaN         NaN         NaN
# mean        NaN  NaN   30.972376   16.900552  105.173481  105.173757
# std         NaN  NaN    1.894535    5.765121    7.554655    5.985875
# min         NaN  NaN   24.000000    1.000000   85.100000   85.500000
# 25%         NaN  NaN   30.000000   13.000000   99.725000  100.700000
# 50%         NaN  NaN   31.000000   17.000000  104.850000  105.400000
# 75%         NaN  NaN   32.000000   21.000000  110.000000  109.900000
# max         NaN  NaN   36.000000   31.000000  127.100000  120.700000
#
#            BARTHAG        EFG%       EFGD%         TOR  ...         FTR  \
# count   362.000000  362.000000  362.000000  362.000000  ...  362.000000
# unique         NaN         NaN         NaN         NaN  ...         NaN
# top            NaN         NaN         NaN         NaN  ...         NaN
# freq           NaN         NaN         NaN         NaN  ...         NaN
# mean      0.492576   50.403315   50.503867   17.137293  ...   32.980939
# std       0.256077    3.057417    2.403837    2.024946  ...    4.754336
# min       0.028300   41.000000   43.400000   12.000000  ...   21.400000
# 25%       0.282300   48.300000   49.000000   15.800000  ...   29.500000
# 50%       0.457850   50.600000   50.400000   17.050000  ...   32.700000
# 75%       0.730600   52.175000   52.200000   18.300000  ...   36.100000
# max       0.978500   59.900000   58.200000   24.000000  ...   50.000000
#
#               FTRD        2P_O        2P_D        3P_O        3P_D  \
# count   362.000000  362.000000  362.000000  362.000000  362.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     33.119890   50.314088   50.358011   33.708564   33.835912
# std       5.507426    3.384435    2.852914    2.522268    2.041178
# min      16.200000   40.400000   42.800000   24.700000   27.900000
# 25%      29.325000   48.100000   48.400000   32.100000   32.500000
# 50%      32.600000   50.200000   50.500000   33.850000   33.900000
# 75%      36.175000   52.600000   52.300000   35.500000   35.200000
# max      49.200000   62.000000   59.000000   41.200000   40.300000
#
#              ADJ_T         WAB  POSTSEASON       SEED
# count   362.000000  362.000000          68  68.000000
# unique         NaN         NaN           8        NaN
# top            NaN         NaN         R64        NaN
# freq           NaN         NaN          32        NaN
# mean     67.487293   -8.227265         NaN   8.764706
# std       2.436906    6.910128         NaN   4.687607
# min      60.000000  -24.800000         NaN   1.000000
# 25%      65.800000  -12.975000         NaN   5.000000
# 50%      67.400000   -9.100000         NaN   9.000000
# 75%      68.900000   -3.525000         NaN  13.000000
# max      75.100000   11.300000         NaN  16.000000
#
# [11 rows x 23 columns]
